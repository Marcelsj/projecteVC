# %%
import numpy as np
import pandas as pd

# %%
test = pd.read_json("./test.json")

# %%
train = pd.read_json("./train.json")

# %%
# Out:
#                                               0    1    2    3    4
# 0                                grup/grup5.jpg  820  206   43   62
# 1                                grup/grup6.jpg  652  151   44   52
# 2                                grup/grup3.jpg  624  223   42   57
# 3                                grup/grup4.jpg  620  178   42   57
# 4                                grup/grup1.jpg  939  276   58   71
# 5                                grup/grup0.jpg  295  224   37   50
# 6                                grup/grup7.jpg  548  222   47   54
# 7                                grup/grup3.jpg  571  239   42   52
# 8                                grup/grup4.jpg  569  192   42   52
# 9                                grup/grup2.jpg  464  225   39   42
# 10                               grup/grup0.jpg  724  265   44   57
# 11                               grup/grup1.jpg  509  230   40   53
# 12                               grup/grup5.jpg  480  167   39   53
# ...
